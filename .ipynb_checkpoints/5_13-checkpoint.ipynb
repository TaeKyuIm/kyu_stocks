# %%
import pickle
with open('./90_candidate.pickle', 'rb') as f:
    candidates = pickle.load(f)

# %%
from pykrx import stock

# %%
names = []
for candidate in candidates:
    name = stock.get_market_ticker_name(candidate)
    if "스팩" not in name:
        names.append(name)

# %%
names
# Out:
# ['DMS',
#  'DXVX',
#  'GRT',
#  'ITX-AI',
#  'JYP Ent.',
#  'KBG',
#  'KCI',
#  'KT서브마린',
#  'MIT',
#  'TJ미디어',
#  '감성코퍼레이션',
#  '경창산업',
#  '골드앤에스',
#  '글로벌텍스프리',
#  '금화피에스시',
#  '나노브릭',
#  '네오오토',
#  '네오위즈',
#  '녹원씨엔아이',
#  '뉴파워프라즈마',
#  '대양제지',
#  '대원산업',
#  '덴티스',
#  '동일금속',
#  '디아크',
#  '디알젬',
#  '디에스앤엘',
#  '디케이앤디',
#  '라온텍',
#  '루닛',
#  '메가스터디',
#  '메지온',
#  '명성티엔에스',
#  '모베이스전자',
#  '바이오다인',
#  '바텍',
#  '베스파',
#  '브이원텍',
#  '비디아이',
#  '비올',
#  '비즈니스온',
#  '선진뷰티사이언스',
#  '슈어소프트테크',
#  '스마트솔루션즈',
#  '시스웍',
#  '씨앤씨인터내셔널',
#  '아리온',
#  '아이쓰리시스템',
#  '아이씨디',
#  '아이엠',
#  '아이톡시',
#  '아이패밀리에스씨',
#  '아진산업',
#  '어스앤에어로스페이스',
#  '에스디시스템',
#  '에스앤에스텍',
#  '에프앤가이드',
#  '엔브이에이치코리아',
#  '엔지스테크널러지',
#  '엘오티베큠',
#  '엠아이텍',
#  '엠에스오토텍',
#  '예스티',
#  '오리엔탈정공',
#  '오스테오닉',
#  '오스템임플란트',
#  '오파스넷',
#  '와이지엔터테인먼트',
#  '원바이오젠',
#  '원텍',
#  '웨이브일렉트로',
#  '이즈미디어',
#  '이큐셀',
#  '인카금융서비스',
#  '인터로조',
#  '인트로메딕',
#  '일월지엠엘',
#  '정상제이엘에스',
#  '제너셈',
#  '제이브이엠',
#  '제이앤티씨',
#  '제이엘케이',
#  '제이엠아이',
# ...
